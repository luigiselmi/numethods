# %% [markdown]
# # Lorenz attractor
# 3D plot of the Lorenz's attractor (from a Matplotlib [example](https://matplotlib.org/stable/gallery/mplot3d/lorenz_attractor.html)). The Lorenz  model is a set of three differential equations, that is a dynamic system, that represents a highly simplified model of convection.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## The model
# We define a function that takes as input an empty array of triples (x,y,z). Empty means that the values are initialized randomly so that creating the array is fast. The input array will start from an initial condition $(x_0,y_0,z_0)$ and the function will calculate al the next values, at each time step, using the Lorenz's equations.

# %%
def lorenz(xyz, *, s=10, r=28, b=2.667):
    """
    Parameters
    ----------
    xyz : array-like, shape (3,)
       Point of interest in three-dimensional space.
    s, r, b : float
       Parameters defining the Lorenz attractor.

    Returns
    -------
    xyz_dot : array, shape (3,)
       Values of the Lorenz attractor's partial derivatives at *xyz*.
    """
    x, y, z = xyz
    x_dot = s * (y - x)
    y_dot = r * x - y - x * z
    z_dot = x * y - b * z
    return np.array([x_dot, y_dot, z_dot])

# %% [markdown]
# We create the empty array of triples $(x_0,y_0,z_0)$, initializing the first triple, and we compute the next values at each time step using the Lorenz function

# %%
dt = 0.01
num_steps = 10000

xyzs = np.empty((num_steps + 1, 3))  # Need one more for the initial values
xyzs[0] = (0., 1., 1.05)  # Set initial values

for i in range(num_steps):
    xyzs[i + 1] = xyzs[i] + lorenz(xyzs[i]) * dt

# %% [markdown]
# ## Visualization
# The variables x,y,z represent the system's variables. The evolution of the system with time can be represented as a trajectory in the phase space.

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot(*xyzs.T, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")
# Out:
# Text(0.5, 0.92, 'Lorenz Attractor')
